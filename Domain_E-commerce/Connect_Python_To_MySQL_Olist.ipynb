# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('cleaned_customers.csv', 'cleaned_customers'),
    ('cleaned_geolocation.csv', 'cleaned_geolocation'),
    ('cleaned_order_items.csv', 'cleaned_order_items'),
    ('cleaned_order_payments.csv', 'cleaned_order_payments'),
    ('cleaned_order_reviews.csv', 'cleaned_order_reviews'),
    ('cleaned_orders.csv', 'cleaned_orders'),
    ('cleaned_products.csv', 'cleaned_products'),
    ('cleaned_sellers.csv', 'cleaned_sellers')
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='9345',  # Replace with your MySQL password
    database='project_olist'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'D:/Data_Science/Capstone_Projects_DS/My_Capstone_Project_DA/Domain_E-commerce/Cleaned-Dataset_Olist_Marketplace_Sales'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Handle duplicate columns if they exist (e.g., 'total_order_value_x' or 'total_order_value_y')
    if 'total_order_value_x' in df.columns:
        df.drop(columns=['total_order_value_x'], inplace=True)

    if 'total_order_value_y' in df.columns:
        df.rename(columns={'total_order_value_y': 'total_order_value'}, inplace=True)

    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names (removing any spaces)
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)
    print(f"Created table {table_name} if not already exists.")

    # Insert DataFrame data into the MySQL table
    values = [tuple(None if pd.isna(x) else x for x in row) for _, row in df.iterrows()]

    # Insert data in batches to improve performance
    batch_size = 1000
    sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(df.columns))})"
    for i in range(0, len(values), batch_size):
        batch = values[i:i+batch_size]
        cursor.executemany(sql, batch)
        conn.commit()
        print(f"Inserted batch {i // batch_size + 1} into {table_name}.\n")

# Close the connection
conn.close()
print("Database connection closed.")
# Out:
# Processing cleaned_customers.csv
# NaN values before replacement:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Created table cleaned_customers if not already exists.
# Inserted batch 1 into cleaned_customers.
#
# Inserted batch 2 into cleaned_customers.
#
# Inserted batch 3 into cleaned_customers.
#
# Inserted batch 4 into cleaned_customers.
#
# Inserted batch 5 into cleaned_customers.
#
# Inserted batch 6 into cleaned_customers.
#
# Inserted batch 7 into cleaned_customers.
#
# Inserted batch 8 into cleaned_customers.
#
# Inserted batch 9 into cleaned_customers.
#
# Inserted batch 10 into cleaned_customers.
#
# Inserted batch 11 into cleaned_customers.
#
# Inserted batch 12 into cleaned_customers.
#
# Inserted batch 13 into cleaned_customers.
#
# Inserted batch 14 into cleaned_customers.
#
# Inserted batch 15 into cleaned_customers.
#
# Inserted batch 16 into cleaned_customers.
#
# Inserted batch 17 into cleaned_customers.
#
# Inserted batch 18 into cleaned_customers.
#
# Inserted batch 19 into cleaned_customers.
#
# Inserted batch 20 into cleaned_customers.
#
# Inserted batch 21 into cleaned_customers.
#
# Inserted batch 22 into cleaned_customers.
#
# Inserted batch 23 into cleaned_customers.
#
# Inserted batch 24 into cleaned_customers.
#
# Inserted batch 25 into cleaned_customers.
#
# Inserted batch 26 into cleaned_customers.
#
# Inserted batch 27 into cleaned_customers.
#
# Inserted batch 28 into cleaned_customers.
#
# Inserted batch 29 into cleaned_customers.
#
# Inserted batch 30 into cleaned_customers.
#
# Inserted batch 31 into cleaned_customers.
#
# Inserted batch 32 into cleaned_customers.
#
# Inserted batch 33 into cleaned_customers.
#
# Inserted batch 34 into cleaned_customers.
#
# Inserted batch 35 into cleaned_customers.
#
# Inserted batch 36 into cleaned_customers.
#
# Inserted batch 37 into cleaned_customers.
#
# Inserted batch 38 into cleaned_customers.
#
# Inserted batch 39 into cleaned_customers.
#
# Inserted batch 40 into cleaned_customers.
#
# Inserted batch 41 into cleaned_customers.
#
# Inserted batch 42 into cleaned_customers.
#
# Inserted batch 43 into cleaned_customers.
#
# Inserted batch 44 into cleaned_customers.
#
# Inserted batch 45 into cleaned_customers.
#
# Inserted batch 46 into cleaned_customers.
#
# Inserted batch 47 into cleaned_customers.
#
# Inserted batch 48 into cleaned_customers.
#
# Inserted batch 49 into cleaned_customers.
#
# Inserted batch 50 into cleaned_customers.
#
# Inserted batch 51 into cleaned_customers.
#
# Inserted batch 52 into cleaned_customers.
#
# Inserted batch 53 into cleaned_customers.
#
# Inserted batch 54 into cleaned_customers.
#
# Inserted batch 55 into cleaned_customers.
#
# Inserted batch 56 into cleaned_customers.
#
# Inserted batch 57 into cleaned_customers.
#
# Inserted batch 58 into cleaned_customers.
#
# Inserted batch 59 into cleaned_customers.
#
# Inserted batch 60 into cleaned_customers.
#
# Inserted batch 61 into cleaned_customers.
#
# Inserted batch 62 into cleaned_customers.
#
# Inserted batch 63 into cleaned_customers.
#
# Inserted batch 64 into cleaned_customers.
#
# Inserted batch 65 into cleaned_customers.
#
# Inserted batch 66 into cleaned_customers.
#
# Inserted batch 67 into cleaned_customers.
#
# Inserted batch 68 into cleaned_customers.
#
# Inserted batch 69 into cleaned_customers.
#
# Inserted batch 70 into cleaned_customers.
#
# Inserted batch 71 into cleaned_customers.
#
# Inserted batch 72 into cleaned_customers.
#
# Inserted batch 73 into cleaned_customers.
#
# Inserted batch 74 into cleaned_customers.
#
# Inserted batch 75 into cleaned_customers.
#
# Inserted batch 76 into cleaned_customers.
#
# Inserted batch 77 into cleaned_customers.
#
# Inserted batch 78 into cleaned_customers.
#
# Inserted batch 79 into cleaned_customers.
#
# Inserted batch 80 into cleaned_customers.
#
# Inserted batch 81 into cleaned_customers.
#
# Inserted batch 82 into cleaned_customers.
#
# Inserted batch 83 into cleaned_customers.
#
# Inserted batch 84 into cleaned_customers.
#
# Inserted batch 85 into cleaned_customers.
#
# Inserted batch 86 into cleaned_customers.
#
# Inserted batch 87 into cleaned_customers.
#
# Inserted batch 88 into cleaned_customers.
#
# Inserted batch 89 into cleaned_customers.
#
# Inserted batch 90 into cleaned_customers.
#
# Inserted batch 91 into cleaned_customers.
#
# Inserted batch 92 into cleaned_customers.
#
# Inserted batch 93 into cleaned_customers.
#
# Inserted batch 94 into cleaned_customers.
#
# Inserted batch 95 into cleaned_customers.
#
# Inserted batch 96 into cleaned_customers.
#
# Inserted batch 97 into cleaned_customers.
#
# Inserted batch 98 into cleaned_customers.
#
# Inserted batch 99 into cleaned_customers.
#
# Inserted batch 100 into cleaned_customers.
#
# Processing cleaned_geolocation.csv
# NaN values before replacement:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Created table cleaned_geolocation if not already exists.
# Inserted batch 1 into cleaned_geolocation.
#
# Inserted batch 2 into cleaned_geolocation.
#
# Inserted batch 3 into cleaned_geolocation.
#
# Inserted batch 4 into cleaned_geolocation.
#
# Inserted batch 5 into cleaned_geolocation.
#
# Inserted batch 6 into cleaned_geolocation.
#
# Inserted batch 7 into cleaned_geolocation.
#
# Inserted batch 8 into cleaned_geolocation.
#
# Inserted batch 9 into cleaned_geolocation.
#
# Inserted batch 10 into cleaned_geolocation.
#
# Inserted batch 11 into cleaned_geolocation.
#
# Inserted batch 12 into cleaned_geolocation.
#
# Inserted batch 13 into cleaned_geolocation.
#
# Inserted batch 14 into cleaned_geolocation.
#
# Inserted batch 15 into cleaned_geolocation.
#
# Inserted batch 16 into cleaned_geolocation.
#
# Inserted batch 17 into cleaned_geolocation.
#
# Inserted batch 18 into cleaned_geolocation.
#
# Inserted batch 19 into cleaned_geolocation.
#
# Inserted batch 20 into cleaned_geolocation.
#
# Inserted batch 21 into cleaned_geolocation.
#
# Inserted batch 22 into cleaned_geolocation.
#
# Inserted batch 23 into cleaned_geolocation.
#
# Inserted batch 24 into cleaned_geolocation.
#
# Inserted batch 25 into cleaned_geolocation.
#
# Inserted batch 26 into cleaned_geolocation.
#
# Inserted batch 27 into cleaned_geolocation.
#
# Inserted batch 28 into cleaned_geolocation.
#
# Inserted batch 29 into cleaned_geolocation.
#
# Inserted batch 30 into cleaned_geolocation.
#
# Inserted batch 31 into cleaned_geolocation.
#
# Inserted batch 32 into cleaned_geolocation.
#
# Inserted batch 33 into cleaned_geolocation.
#
# Inserted batch 34 into cleaned_geolocation.
#
# Inserted batch 35 into cleaned_geolocation.
#
# Inserted batch 36 into cleaned_geolocation.
#
# Inserted batch 37 into cleaned_geolocation.
#
# Inserted batch 38 into cleaned_geolocation.
#
# Inserted batch 39 into cleaned_geolocation.
#
# Inserted batch 40 into cleaned_geolocation.
#
# Inserted batch 41 into cleaned_geolocation.
#
# Inserted batch 42 into cleaned_geolocation.
#
# Inserted batch 43 into cleaned_geolocation.
#
# Inserted batch 44 into cleaned_geolocation.
#
# Inserted batch 45 into cleaned_geolocation.
#
# Inserted batch 46 into cleaned_geolocation.
#
# Inserted batch 47 into cleaned_geolocation.
#
# Inserted batch 48 into cleaned_geolocation.
#
# Inserted batch 49 into cleaned_geolocation.
#
# Inserted batch 50 into cleaned_geolocation.
#
# Inserted batch 51 into cleaned_geolocation.
#
# Inserted batch 52 into cleaned_geolocation.
#
# Inserted batch 53 into cleaned_geolocation.
#
# Inserted batch 54 into cleaned_geolocation.
#
# Inserted batch 55 into cleaned_geolocation.
#
# Inserted batch 56 into cleaned_geolocation.
#
# Inserted batch 57 into cleaned_geolocation.
#
# Inserted batch 58 into cleaned_geolocation.
#
# Inserted batch 59 into cleaned_geolocation.
#
# Inserted batch 60 into cleaned_geolocation.
#
# Inserted batch 61 into cleaned_geolocation.
#
# Inserted batch 62 into cleaned_geolocation.
#
# Inserted batch 63 into cleaned_geolocation.
#
# Inserted batch 64 into cleaned_geolocation.
#
# Inserted batch 65 into cleaned_geolocation.
#
# Inserted batch 66 into cleaned_geolocation.
#
# Inserted batch 67 into cleaned_geolocation.
#
# Inserted batch 68 into cleaned_geolocation.
#
# Inserted batch 69 into cleaned_geolocation.
#
# Inserted batch 70 into cleaned_geolocation.
#
# Inserted batch 71 into cleaned_geolocation.
#
# Inserted batch 72 into cleaned_geolocation.
#
# Inserted batch 73 into cleaned_geolocation.
#
# Inserted batch 74 into cleaned_geolocation.
#
# Inserted batch 75 into cleaned_geolocation.
#
# Inserted batch 76 into cleaned_geolocation.
#
# Inserted batch 77 into cleaned_geolocation.
#
# Inserted batch 78 into cleaned_geolocation.
#
# Inserted batch 79 into cleaned_geolocation.
#
# Inserted batch 80 into cleaned_geolocation.
#
# Inserted batch 81 into cleaned_geolocation.
#
# Inserted batch 82 into cleaned_geolocation.
#
# Inserted batch 83 into cleaned_geolocation.
#
# Inserted batch 84 into cleaned_geolocation.
#
# Inserted batch 85 into cleaned_geolocation.
#
# Inserted batch 86 into cleaned_geolocation.
#
# Inserted batch 87 into cleaned_geolocation.
#
# Inserted batch 88 into cleaned_geolocation.
#
# Inserted batch 89 into cleaned_geolocation.
#
# Inserted batch 90 into cleaned_geolocation.
#
# Inserted batch 91 into cleaned_geolocation.
#
# Inserted batch 92 into cleaned_geolocation.
#
# Inserted batch 93 into cleaned_geolocation.
#
# Inserted batch 94 into cleaned_geolocation.
#
# Inserted batch 95 into cleaned_geolocation.
#
# Inserted batch 96 into cleaned_geolocation.
#
# Inserted batch 97 into cleaned_geolocation.
#
# Inserted batch 98 into cleaned_geolocation.
#
# Inserted batch 99 into cleaned_geolocation.
#
# Inserted batch 100 into cleaned_geolocation.
#
# Inserted batch 101 into cleaned_geolocation.
#
# Inserted batch 102 into cleaned_geolocation.
#
# Inserted batch 103 into cleaned_geolocation.
#
# Inserted batch 104 into cleaned_geolocation.
#
# Inserted batch 105 into cleaned_geolocation.
#
# Inserted batch 106 into cleaned_geolocation.
#
# Inserted batch 107 into cleaned_geolocation.
#
# Inserted batch 108 into cleaned_geolocation.
#
# Inserted batch 109 into cleaned_geolocation.
#
# Inserted batch 110 into cleaned_geolocation.
#
# Inserted batch 111 into cleaned_geolocation.
#
# Inserted batch 112 into cleaned_geolocation.
#
# Inserted batch 113 into cleaned_geolocation.
#
# Inserted batch 114 into cleaned_geolocation.
#
# Inserted batch 115 into cleaned_geolocation.
#
# Inserted batch 116 into cleaned_geolocation.
#
# Inserted batch 117 into cleaned_geolocation.
#
# Inserted batch 118 into cleaned_geolocation.
#
# Inserted batch 119 into cleaned_geolocation.
#
# Inserted batch 120 into cleaned_geolocation.
#
# Inserted batch 121 into cleaned_geolocation.
#
# Inserted batch 122 into cleaned_geolocation.
#
# Inserted batch 123 into cleaned_geolocation.
#
# Inserted batch 124 into cleaned_geolocation.
#
# Inserted batch 125 into cleaned_geolocation.
#
# Inserted batch 126 into cleaned_geolocation.
#
# Inserted batch 127 into cleaned_geolocation.
#
# Inserted batch 128 into cleaned_geolocation.
#
# Inserted batch 129 into cleaned_geolocation.
#
# Inserted batch 130 into cleaned_geolocation.
#
# Inserted batch 131 into cleaned_geolocation.
#
# Inserted batch 132 into cleaned_geolocation.
#
# Inserted batch 133 into cleaned_geolocation.
#
# Inserted batch 134 into cleaned_geolocation.
#
# Inserted batch 135 into cleaned_geolocation.
#
# Inserted batch 136 into cleaned_geolocation.
#
# Inserted batch 137 into cleaned_geolocation.
#
# Inserted batch 138 into cleaned_geolocation.
#
# Inserted batch 139 into cleaned_geolocation.
#
# Inserted batch 140 into cleaned_geolocation.
#
# Inserted batch 141 into cleaned_geolocation.
#
# Inserted batch 142 into cleaned_geolocation.
#
# Inserted batch 143 into cleaned_geolocation.
#
# Inserted batch 144 into cleaned_geolocation.
#
# Inserted batch 145 into cleaned_geolocation.
#
# Inserted batch 146 into cleaned_geolocation.
#
# Inserted batch 147 into cleaned_geolocation.
#
# Inserted batch 148 into cleaned_geolocation.
#
# Inserted batch 149 into cleaned_geolocation.
#
# Inserted batch 150 into cleaned_geolocation.
#
# Inserted batch 151 into cleaned_geolocation.
#
# Inserted batch 152 into cleaned_geolocation.
#
# Inserted batch 153 into cleaned_geolocation.
#
# Inserted batch 154 into cleaned_geolocation.
#
# Inserted batch 155 into cleaned_geolocation.
#
# Inserted batch 156 into cleaned_geolocation.
#
# Inserted batch 157 into cleaned_geolocation.
#
# Inserted batch 158 into cleaned_geolocation.
#
# Inserted batch 159 into cleaned_geolocation.
#
# Inserted batch 160 into cleaned_geolocation.
#
# Inserted batch 161 into cleaned_geolocation.
#
# Inserted batch 162 into cleaned_geolocation.
#
# Inserted batch 163 into cleaned_geolocation.
#
# Inserted batch 164 into cleaned_geolocation.
#
# Inserted batch 165 into cleaned_geolocation.
#
# Inserted batch 166 into cleaned_geolocation.
#
# Inserted batch 167 into cleaned_geolocation.
#
# Inserted batch 168 into cleaned_geolocation.
#
# Inserted batch 169 into cleaned_geolocation.
#
# Inserted batch 170 into cleaned_geolocation.
#
# Inserted batch 171 into cleaned_geolocation.
#
# Inserted batch 172 into cleaned_geolocation.
#
# Inserted batch 173 into cleaned_geolocation.
#
# Inserted batch 174 into cleaned_geolocation.
#
# Inserted batch 175 into cleaned_geolocation.
#
# Inserted batch 176 into cleaned_geolocation.
#
# Inserted batch 177 into cleaned_geolocation.
#
# Inserted batch 178 into cleaned_geolocation.
#
# Inserted batch 179 into cleaned_geolocation.
#
# Inserted batch 180 into cleaned_geolocation.
#
# Inserted batch 181 into cleaned_geolocation.
#
# Inserted batch 182 into cleaned_geolocation.
#
# Inserted batch 183 into cleaned_geolocation.
#
# Inserted batch 184 into cleaned_geolocation.
#
# Inserted batch 185 into cleaned_geolocation.
#
# Inserted batch 186 into cleaned_geolocation.
#
# Inserted batch 187 into cleaned_geolocation.
#
# Inserted batch 188 into cleaned_geolocation.
#
# Inserted batch 189 into cleaned_geolocation.
#
# Inserted batch 190 into cleaned_geolocation.
#
# Inserted batch 191 into cleaned_geolocation.
#
# Inserted batch 192 into cleaned_geolocation.
#
# Inserted batch 193 into cleaned_geolocation.
#
# Inserted batch 194 into cleaned_geolocation.
#
# Inserted batch 195 into cleaned_geolocation.
#
# Inserted batch 196 into cleaned_geolocation.
#
# Inserted batch 197 into cleaned_geolocation.
#
# Inserted batch 198 into cleaned_geolocation.
#
# Inserted batch 199 into cleaned_geolocation.
#
# Inserted batch 200 into cleaned_geolocation.
#
# Inserted batch 201 into cleaned_geolocation.
#
# Inserted batch 202 into cleaned_geolocation.
#
# Inserted batch 203 into cleaned_geolocation.
#
# Inserted batch 204 into cleaned_geolocation.
#
# Inserted batch 205 into cleaned_geolocation.
#
# Inserted batch 206 into cleaned_geolocation.
#
# Inserted batch 207 into cleaned_geolocation.
#
# Inserted batch 208 into cleaned_geolocation.
#
# Inserted batch 209 into cleaned_geolocation.
#
# Inserted batch 210 into cleaned_geolocation.
#
# Inserted batch 211 into cleaned_geolocation.
#
# Inserted batch 212 into cleaned_geolocation.
#
# Inserted batch 213 into cleaned_geolocation.
#
# Inserted batch 214 into cleaned_geolocation.
#
# Inserted batch 215 into cleaned_geolocation.
#
# Inserted batch 216 into cleaned_geolocation.
#
# Inserted batch 217 into cleaned_geolocation.
#
# Inserted batch 218 into cleaned_geolocation.
#
# Inserted batch 219 into cleaned_geolocation.
#
# Inserted batch 220 into cleaned_geolocation.
#
# Inserted batch 221 into cleaned_geolocation.
#
# Inserted batch 222 into cleaned_geolocation.
#
# Inserted batch 223 into cleaned_geolocation.
#
# Inserted batch 224 into cleaned_geolocation.
#
# Inserted batch 225 into cleaned_geolocation.
#
# Inserted batch 226 into cleaned_geolocation.
#
# Inserted batch 227 into cleaned_geolocation.
#
# Inserted batch 228 into cleaned_geolocation.
#
# Inserted batch 229 into cleaned_geolocation.
#
# Inserted batch 230 into cleaned_geolocation.
#
# Inserted batch 231 into cleaned_geolocation.
#
# Inserted batch 232 into cleaned_geolocation.
#
# Inserted batch 233 into cleaned_geolocation.
#
# Inserted batch 234 into cleaned_geolocation.
#
# Inserted batch 235 into cleaned_geolocation.
#
# Inserted batch 236 into cleaned_geolocation.
#
# Inserted batch 237 into cleaned_geolocation.
#
# Inserted batch 238 into cleaned_geolocation.
#
# Inserted batch 239 into cleaned_geolocation.
#
# Inserted batch 240 into cleaned_geolocation.
#
# Inserted batch 241 into cleaned_geolocation.
#
# Inserted batch 242 into cleaned_geolocation.
#
# Inserted batch 243 into cleaned_geolocation.
#
# Inserted batch 244 into cleaned_geolocation.
#
# Inserted batch 245 into cleaned_geolocation.
#
# Inserted batch 246 into cleaned_geolocation.
#
# Inserted batch 247 into cleaned_geolocation.
#
# Inserted batch 248 into cleaned_geolocation.
#
# Inserted batch 249 into cleaned_geolocation.
#
# Inserted batch 250 into cleaned_geolocation.
#
# Inserted batch 251 into cleaned_geolocation.
#
# Inserted batch 252 into cleaned_geolocation.
#
# Inserted batch 253 into cleaned_geolocation.
#
# Inserted batch 254 into cleaned_geolocation.
#
# Inserted batch 255 into cleaned_geolocation.
#
# Inserted batch 256 into cleaned_geolocation.
#
# Inserted batch 257 into cleaned_geolocation.
#
# Inserted batch 258 into cleaned_geolocation.
#
# Inserted batch 259 into cleaned_geolocation.
#
# Inserted batch 260 into cleaned_geolocation.
#
# Inserted batch 261 into cleaned_geolocation.
#
# Inserted batch 262 into cleaned_geolocation.
#
# Inserted batch 263 into cleaned_geolocation.
#
# Inserted batch 264 into cleaned_geolocation.
#
# Inserted batch 265 into cleaned_geolocation.
#
# Inserted batch 266 into cleaned_geolocation.
#
# Inserted batch 267 into cleaned_geolocation.
#
# Inserted batch 268 into cleaned_geolocation.
#
# Inserted batch 269 into cleaned_geolocation.
#
# Inserted batch 270 into cleaned_geolocation.
#
# Inserted batch 271 into cleaned_geolocation.
#
# Inserted batch 272 into cleaned_geolocation.
#
# Inserted batch 273 into cleaned_geolocation.
#
# Inserted batch 274 into cleaned_geolocation.
#
# Inserted batch 275 into cleaned_geolocation.
#
# Inserted batch 276 into cleaned_geolocation.
#
# Inserted batch 277 into cleaned_geolocation.
#
# Inserted batch 278 into cleaned_geolocation.
#
# Inserted batch 279 into cleaned_geolocation.
#
# Inserted batch 280 into cleaned_geolocation.
#
# Inserted batch 281 into cleaned_geolocation.
#
# Inserted batch 282 into cleaned_geolocation.
#
# Inserted batch 283 into cleaned_geolocation.
#
# Inserted batch 284 into cleaned_geolocation.
#
# Inserted batch 285 into cleaned_geolocation.
#
# Inserted batch 286 into cleaned_geolocation.
#
# Inserted batch 287 into cleaned_geolocation.
#
# Inserted batch 288 into cleaned_geolocation.
#
# Inserted batch 289 into cleaned_geolocation.
#
# Inserted batch 290 into cleaned_geolocation.
#
# Inserted batch 291 into cleaned_geolocation.
#
# Inserted batch 292 into cleaned_geolocation.
#
# Inserted batch 293 into cleaned_geolocation.
#
# Inserted batch 294 into cleaned_geolocation.
#
# Inserted batch 295 into cleaned_geolocation.
#
# Inserted batch 296 into cleaned_geolocation.
#
# Inserted batch 297 into cleaned_geolocation.
#
# Inserted batch 298 into cleaned_geolocation.
#
# Inserted batch 299 into cleaned_geolocation.
#
# Inserted batch 300 into cleaned_geolocation.
#
# Inserted batch 301 into cleaned_geolocation.
#
# Inserted batch 302 into cleaned_geolocation.
#
# Inserted batch 303 into cleaned_geolocation.
#
# Inserted batch 304 into cleaned_geolocation.
#
# Inserted batch 305 into cleaned_geolocation.
#
# Inserted batch 306 into cleaned_geolocation.
#
# Inserted batch 307 into cleaned_geolocation.
#
# Inserted batch 308 into cleaned_geolocation.
#
# Inserted batch 309 into cleaned_geolocation.
#
# Inserted batch 310 into cleaned_geolocation.
#
# Inserted batch 311 into cleaned_geolocation.
#
# Inserted batch 312 into cleaned_geolocation.
#
# Inserted batch 313 into cleaned_geolocation.
#
# Inserted batch 314 into cleaned_geolocation.
#
# Inserted batch 315 into cleaned_geolocation.
#
# Inserted batch 316 into cleaned_geolocation.
#
# Inserted batch 317 into cleaned_geolocation.
#
# Inserted batch 318 into cleaned_geolocation.
#
# Inserted batch 319 into cleaned_geolocation.
#
# Inserted batch 320 into cleaned_geolocation.
#
# Inserted batch 321 into cleaned_geolocation.
#
# Inserted batch 322 into cleaned_geolocation.
#
# Inserted batch 323 into cleaned_geolocation.
#
# Inserted batch 324 into cleaned_geolocation.
#
# Inserted batch 325 into cleaned_geolocation.
#
# Inserted batch 326 into cleaned_geolocation.
#
# Inserted batch 327 into cleaned_geolocation.
#
# Inserted batch 328 into cleaned_geolocation.
#
# Inserted batch 329 into cleaned_geolocation.
#
# Inserted batch 330 into cleaned_geolocation.
#
# Inserted batch 331 into cleaned_geolocation.
#
# Inserted batch 332 into cleaned_geolocation.
#
# Inserted batch 333 into cleaned_geolocation.
#
# Inserted batch 334 into cleaned_geolocation.
#
# Inserted batch 335 into cleaned_geolocation.
#
# Inserted batch 336 into cleaned_geolocation.
#
# Inserted batch 337 into cleaned_geolocation.
#
# Inserted batch 338 into cleaned_geolocation.
#
# Inserted batch 339 into cleaned_geolocation.
#
# Inserted batch 340 into cleaned_geolocation.
#
# Inserted batch 341 into cleaned_geolocation.
#
# Inserted batch 342 into cleaned_geolocation.
#
# Inserted batch 343 into cleaned_geolocation.
#
# Inserted batch 344 into cleaned_geolocation.
#
# Inserted batch 345 into cleaned_geolocation.
#
# Inserted batch 346 into cleaned_geolocation.
#
# Inserted batch 347 into cleaned_geolocation.
#
# Inserted batch 348 into cleaned_geolocation.
#
# Inserted batch 349 into cleaned_geolocation.
#
# Inserted batch 350 into cleaned_geolocation.
#
# Inserted batch 351 into cleaned_geolocation.
#
# Inserted batch 352 into cleaned_geolocation.
#
# Inserted batch 353 into cleaned_geolocation.
#
# Inserted batch 354 into cleaned_geolocation.
#
# Inserted batch 355 into cleaned_geolocation.
#
# Inserted batch 356 into cleaned_geolocation.
#
# Inserted batch 357 into cleaned_geolocation.
#
# Inserted batch 358 into cleaned_geolocation.
#
# Inserted batch 359 into cleaned_geolocation.
#
# Inserted batch 360 into cleaned_geolocation.
#
# Inserted batch 361 into cleaned_geolocation.
#
# Inserted batch 362 into cleaned_geolocation.
#
# Inserted batch 363 into cleaned_geolocation.
#
# Inserted batch 364 into cleaned_geolocation.
#
# Inserted batch 365 into cleaned_geolocation.
#
# Inserted batch 366 into cleaned_geolocation.
#
# Inserted batch 367 into cleaned_geolocation.
#
# Inserted batch 368 into cleaned_geolocation.
#
# Inserted batch 369 into cleaned_geolocation.
#
# Inserted batch 370 into cleaned_geolocation.
#
# Inserted batch 371 into cleaned_geolocation.
#
# Inserted batch 372 into cleaned_geolocation.
#
# Inserted batch 373 into cleaned_geolocation.
#
# Inserted batch 374 into cleaned_geolocation.
#
# Inserted batch 375 into cleaned_geolocation.
#
# Inserted batch 376 into cleaned_geolocation.
#
# Inserted batch 377 into cleaned_geolocation.
#
# Inserted batch 378 into cleaned_geolocation.
#
# Inserted batch 379 into cleaned_geolocation.
#
# Inserted batch 380 into cleaned_geolocation.
#
# Inserted batch 381 into cleaned_geolocation.
#
# Inserted batch 382 into cleaned_geolocation.
#
# Inserted batch 383 into cleaned_geolocation.
#
# Inserted batch 384 into cleaned_geolocation.
#
# Inserted batch 385 into cleaned_geolocation.
#
# Inserted batch 386 into cleaned_geolocation.
#
# Inserted batch 387 into cleaned_geolocation.
#
# Inserted batch 388 into cleaned_geolocation.
#
# Inserted batch 389 into cleaned_geolocation.
#
# Inserted batch 390 into cleaned_geolocation.
#
# Inserted batch 391 into cleaned_geolocation.
#
# Inserted batch 392 into cleaned_geolocation.
#
# Inserted batch 393 into cleaned_geolocation.
#
# Inserted batch 394 into cleaned_geolocation.
#
# Inserted batch 395 into cleaned_geolocation.
#
# Inserted batch 396 into cleaned_geolocation.
#
# Inserted batch 397 into cleaned_geolocation.
#
# Inserted batch 398 into cleaned_geolocation.
#
# Inserted batch 399 into cleaned_geolocation.
#
# Inserted batch 400 into cleaned_geolocation.
#
# Inserted batch 401 into cleaned_geolocation.
#
# Inserted batch 402 into cleaned_geolocation.
#
# Inserted batch 403 into cleaned_geolocation.
#
# Inserted batch 404 into cleaned_geolocation.
#
# Inserted batch 405 into cleaned_geolocation.
#
# Inserted batch 406 into cleaned_geolocation.
#
# Inserted batch 407 into cleaned_geolocation.
#
# Inserted batch 408 into cleaned_geolocation.
#
# Inserted batch 409 into cleaned_geolocation.
#
# Inserted batch 410 into cleaned_geolocation.
#
# Inserted batch 411 into cleaned_geolocation.
#
# Inserted batch 412 into cleaned_geolocation.
#
# Inserted batch 413 into cleaned_geolocation.
#
# Inserted batch 414 into cleaned_geolocation.
#
# Inserted batch 415 into cleaned_geolocation.
#
# Inserted batch 416 into cleaned_geolocation.
#
# Inserted batch 417 into cleaned_geolocation.
#
# Inserted batch 418 into cleaned_geolocation.
#
# Inserted batch 419 into cleaned_geolocation.
#
# Inserted batch 420 into cleaned_geolocation.
#
# Inserted batch 421 into cleaned_geolocation.
#
# Inserted batch 422 into cleaned_geolocation.
#
# Inserted batch 423 into cleaned_geolocation.
#
# Inserted batch 424 into cleaned_geolocation.
#
# Inserted batch 425 into cleaned_geolocation.
#
# Inserted batch 426 into cleaned_geolocation.
#
# Inserted batch 427 into cleaned_geolocation.
#
# Inserted batch 428 into cleaned_geolocation.
#
# Inserted batch 429 into cleaned_geolocation.
#
# Inserted batch 430 into cleaned_geolocation.
#
# Inserted batch 431 into cleaned_geolocation.
#
# Inserted batch 432 into cleaned_geolocation.
#
# Inserted batch 433 into cleaned_geolocation.
#
# Inserted batch 434 into cleaned_geolocation.
#
# Inserted batch 435 into cleaned_geolocation.
#
# Inserted batch 436 into cleaned_geolocation.
#
# Inserted batch 437 into cleaned_geolocation.
#
# Inserted batch 438 into cleaned_geolocation.
#
# Inserted batch 439 into cleaned_geolocation.
#
# Inserted batch 440 into cleaned_geolocation.
#
# Inserted batch 441 into cleaned_geolocation.
#
# Inserted batch 442 into cleaned_geolocation.
#
# Inserted batch 443 into cleaned_geolocation.
#
# Inserted batch 444 into cleaned_geolocation.
#
# Inserted batch 445 into cleaned_geolocation.
#
# Inserted batch 446 into cleaned_geolocation.
#
# Inserted batch 447 into cleaned_geolocation.
#
# Inserted batch 448 into cleaned_geolocation.
#
# Inserted batch 449 into cleaned_geolocation.
#
# Inserted batch 450 into cleaned_geolocation.
#
# Inserted batch 451 into cleaned_geolocation.
#
# Inserted batch 452 into cleaned_geolocation.
#
# Inserted batch 453 into cleaned_geolocation.
#
# Inserted batch 454 into cleaned_geolocation.
#
# Inserted batch 455 into cleaned_geolocation.
#
# Inserted batch 456 into cleaned_geolocation.
#
# Inserted batch 457 into cleaned_geolocation.
#
# Inserted batch 458 into cleaned_geolocation.
#
# Inserted batch 459 into cleaned_geolocation.
#
# Inserted batch 460 into cleaned_geolocation.
#
# Inserted batch 461 into cleaned_geolocation.
#
# Inserted batch 462 into cleaned_geolocation.
#
# Inserted batch 463 into cleaned_geolocation.
#
# Inserted batch 464 into cleaned_geolocation.
#
# Inserted batch 465 into cleaned_geolocation.
#
# Inserted batch 466 into cleaned_geolocation.
#
# Inserted batch 467 into cleaned_geolocation.
#
# Inserted batch 468 into cleaned_geolocation.
#
# Inserted batch 469 into cleaned_geolocation.
#
# Inserted batch 470 into cleaned_geolocation.
#
# Inserted batch 471 into cleaned_geolocation.
#
# Inserted batch 472 into cleaned_geolocation.
#
# Inserted batch 473 into cleaned_geolocation.
#
# Inserted batch 474 into cleaned_geolocation.
#
# Inserted batch 475 into cleaned_geolocation.
#
# Inserted batch 476 into cleaned_geolocation.
#
# Inserted batch 477 into cleaned_geolocation.
#
# Inserted batch 478 into cleaned_geolocation.
#
# Inserted batch 479 into cleaned_geolocation.
#
# Inserted batch 480 into cleaned_geolocation.
#
# Inserted batch 481 into cleaned_geolocation.
#
# Inserted batch 482 into cleaned_geolocation.
#
# Inserted batch 483 into cleaned_geolocation.
#
# Inserted batch 484 into cleaned_geolocation.
#
# Inserted batch 485 into cleaned_geolocation.
#
# Inserted batch 486 into cleaned_geolocation.
#
# Inserted batch 487 into cleaned_geolocation.
#
# Inserted batch 488 into cleaned_geolocation.
#
# Inserted batch 489 into cleaned_geolocation.
#
# Inserted batch 490 into cleaned_geolocation.
#
# Inserted batch 491 into cleaned_geolocation.
#
# Inserted batch 492 into cleaned_geolocation.
#
# Inserted batch 493 into cleaned_geolocation.
#
# Inserted batch 494 into cleaned_geolocation.
#
# Inserted batch 495 into cleaned_geolocation.
#
# Inserted batch 496 into cleaned_geolocation.
#
# Inserted batch 497 into cleaned_geolocation.
#
# Inserted batch 498 into cleaned_geolocation.
#
# Inserted batch 499 into cleaned_geolocation.
#
# Inserted batch 500 into cleaned_geolocation.
#
# Inserted batch 501 into cleaned_geolocation.
#
# Inserted batch 502 into cleaned_geolocation.
#
# Inserted batch 503 into cleaned_geolocation.
#
# Inserted batch 504 into cleaned_geolocation.
#
# Inserted batch 505 into cleaned_geolocation.
#
# Inserted batch 506 into cleaned_geolocation.
#
# Inserted batch 507 into cleaned_geolocation.
#
# Inserted batch 508 into cleaned_geolocation.
#
# Inserted batch 509 into cleaned_geolocation.
#
# Inserted batch 510 into cleaned_geolocation.
#
# Inserted batch 511 into cleaned_geolocation.
#
# Inserted batch 512 into cleaned_geolocation.
#
# Inserted batch 513 into cleaned_geolocation.
#
# Inserted batch 514 into cleaned_geolocation.
#
# Inserted batch 515 into cleaned_geolocation.
#
# Inserted batch 516 into cleaned_geolocation.
#
# Inserted batch 517 into cleaned_geolocation.
#
# Inserted batch 518 into cleaned_geolocation.
#
# Inserted batch 519 into cleaned_geolocation.
#
# Inserted batch 520 into cleaned_geolocation.
#
# Inserted batch 521 into cleaned_geolocation.
#
# Inserted batch 522 into cleaned_geolocation.
#
# Inserted batch 523 into cleaned_geolocation.
#
# Inserted batch 524 into cleaned_geolocation.
#
# Inserted batch 525 into cleaned_geolocation.
#
# Inserted batch 526 into cleaned_geolocation.
#
# Inserted batch 527 into cleaned_geolocation.
#
# Inserted batch 528 into cleaned_geolocation.
#
# Inserted batch 529 into cleaned_geolocation.
#
# Inserted batch 530 into cleaned_geolocation.
#
# Inserted batch 531 into cleaned_geolocation.
#
# Inserted batch 532 into cleaned_geolocation.
#
# Inserted batch 533 into cleaned_geolocation.
#
# Inserted batch 534 into cleaned_geolocation.
#
# Inserted batch 535 into cleaned_geolocation.
#
# Inserted batch 536 into cleaned_geolocation.
#
# Inserted batch 537 into cleaned_geolocation.
#
# Inserted batch 538 into cleaned_geolocation.
#
# Inserted batch 539 into cleaned_geolocation.
#
# Inserted batch 540 into cleaned_geolocation.
#
# Inserted batch 541 into cleaned_geolocation.
#
# Inserted batch 542 into cleaned_geolocation.
#
# Inserted batch 543 into cleaned_geolocation.
#
# Inserted batch 544 into cleaned_geolocation.
#
# Inserted batch 545 into cleaned_geolocation.
#
# Inserted batch 546 into cleaned_geolocation.
#
# Inserted batch 547 into cleaned_geolocation.
#
# Inserted batch 548 into cleaned_geolocation.
#
# Inserted batch 549 into cleaned_geolocation.
#
# Inserted batch 550 into cleaned_geolocation.
#
# Inserted batch 551 into cleaned_geolocation.
#
# Inserted batch 552 into cleaned_geolocation.
#
# Inserted batch 553 into cleaned_geolocation.
#
# Inserted batch 554 into cleaned_geolocation.
#
# Inserted batch 555 into cleaned_geolocation.
#
# Inserted batch 556 into cleaned_geolocation.
#
# Inserted batch 557 into cleaned_geolocation.
#
# Inserted batch 558 into cleaned_geolocation.
#
# Inserted batch 559 into cleaned_geolocation.
#
# Inserted batch 560 into cleaned_geolocation.
#
# Inserted batch 561 into cleaned_geolocation.
#
# Inserted batch 562 into cleaned_geolocation.
#
# Inserted batch 563 into cleaned_geolocation.
#
# Inserted batch 564 into cleaned_geolocation.
#
# Inserted batch 565 into cleaned_geolocation.
#
# Inserted batch 566 into cleaned_geolocation.
#
# Inserted batch 567 into cleaned_geolocation.
#
# Inserted batch 568 into cleaned_geolocation.
#
# Inserted batch 569 into cleaned_geolocation.
#
# Inserted batch 570 into cleaned_geolocation.
#
# Inserted batch 571 into cleaned_geolocation.
#
# Inserted batch 572 into cleaned_geolocation.
#
# Inserted batch 573 into cleaned_geolocation.
#
# Inserted batch 574 into cleaned_geolocation.
#
# Inserted batch 575 into cleaned_geolocation.
#
# Inserted batch 576 into cleaned_geolocation.
#
# Inserted batch 577 into cleaned_geolocation.
#
# Inserted batch 578 into cleaned_geolocation.
#
# Inserted batch 579 into cleaned_geolocation.
#
# Inserted batch 580 into cleaned_geolocation.
#
# Inserted batch 581 into cleaned_geolocation.
#
# Inserted batch 582 into cleaned_geolocation.
#
# Inserted batch 583 into cleaned_geolocation.
#
# Inserted batch 584 into cleaned_geolocation.
#
# Inserted batch 585 into cleaned_geolocation.
#
# Inserted batch 586 into cleaned_geolocation.
#
# Inserted batch 587 into cleaned_geolocation.
#
# Inserted batch 588 into cleaned_geolocation.
#
# Inserted batch 589 into cleaned_geolocation.
#
# Inserted batch 590 into cleaned_geolocation.
#
# Inserted batch 591 into cleaned_geolocation.
#
# Inserted batch 592 into cleaned_geolocation.
#
# Inserted batch 593 into cleaned_geolocation.
#
# Inserted batch 594 into cleaned_geolocation.
#
# Inserted batch 595 into cleaned_geolocation.
#
# Inserted batch 596 into cleaned_geolocation.
#
# Inserted batch 597 into cleaned_geolocation.
#
# Inserted batch 598 into cleaned_geolocation.
#
# Inserted batch 599 into cleaned_geolocation.
#
# Inserted batch 600 into cleaned_geolocation.
#
# Inserted batch 601 into cleaned_geolocation.
#
# Inserted batch 602 into cleaned_geolocation.
#
# Inserted batch 603 into cleaned_geolocation.
#
# Inserted batch 604 into cleaned_geolocation.
#
# Inserted batch 605 into cleaned_geolocation.
#
# Inserted batch 606 into cleaned_geolocation.
#
# Inserted batch 607 into cleaned_geolocation.
#
# Inserted batch 608 into cleaned_geolocation.
#
# Inserted batch 609 into cleaned_geolocation.
#
# Inserted batch 610 into cleaned_geolocation.
#
# Inserted batch 611 into cleaned_geolocation.
#
# Inserted batch 612 into cleaned_geolocation.
#
# Inserted batch 613 into cleaned_geolocation.
#
# Inserted batch 614 into cleaned_geolocation.
#
# Inserted batch 615 into cleaned_geolocation.
#
# Inserted batch 616 into cleaned_geolocation.
#
# Inserted batch 617 into cleaned_geolocation.
#
# Inserted batch 618 into cleaned_geolocation.
#
# Inserted batch 619 into cleaned_geolocation.
#
# Inserted batch 620 into cleaned_geolocation.
#
# Inserted batch 621 into cleaned_geolocation.
#
# Inserted batch 622 into cleaned_geolocation.
#
# Inserted batch 623 into cleaned_geolocation.
#
# Inserted batch 624 into cleaned_geolocation.
#
# Inserted batch 625 into cleaned_geolocation.
#
# Inserted batch 626 into cleaned_geolocation.
#
# Inserted batch 627 into cleaned_geolocation.
#
# Inserted batch 628 into cleaned_geolocation.
#
# Inserted batch 629 into cleaned_geolocation.
#
# Inserted batch 630 into cleaned_geolocation.
#
# Inserted batch 631 into cleaned_geolocation.
#
# Inserted batch 632 into cleaned_geolocation.
#
# Inserted batch 633 into cleaned_geolocation.
#
# Inserted batch 634 into cleaned_geolocation.
#
# Inserted batch 635 into cleaned_geolocation.
#
# Inserted batch 636 into cleaned_geolocation.
#
# Inserted batch 637 into cleaned_geolocation.
#
# Inserted batch 638 into cleaned_geolocation.
#
# Inserted batch 639 into cleaned_geolocation.
#
# Inserted batch 640 into cleaned_geolocation.
#
# Inserted batch 641 into cleaned_geolocation.
#
# Inserted batch 642 into cleaned_geolocation.
#
# Inserted batch 643 into cleaned_geolocation.
#
# Inserted batch 644 into cleaned_geolocation.
#
# Inserted batch 645 into cleaned_geolocation.
#
# Inserted batch 646 into cleaned_geolocation.
#
# Inserted batch 647 into cleaned_geolocation.
#
# Inserted batch 648 into cleaned_geolocation.
#
# Inserted batch 649 into cleaned_geolocation.
#
# Inserted batch 650 into cleaned_geolocation.
#
# Inserted batch 651 into cleaned_geolocation.
#
# Inserted batch 652 into cleaned_geolocation.
#
# Inserted batch 653 into cleaned_geolocation.
#
# Inserted batch 654 into cleaned_geolocation.
#
# Inserted batch 655 into cleaned_geolocation.
#
# Inserted batch 656 into cleaned_geolocation.
#
# Inserted batch 657 into cleaned_geolocation.
#
# Inserted batch 658 into cleaned_geolocation.
#
# Inserted batch 659 into cleaned_geolocation.
#
# Inserted batch 660 into cleaned_geolocation.
#
# Inserted batch 661 into cleaned_geolocation.
#
# Inserted batch 662 into cleaned_geolocation.
#
# Inserted batch 663 into cleaned_geolocation.
#
# Inserted batch 664 into cleaned_geolocation.
#
# Inserted batch 665 into cleaned_geolocation.
#
# Inserted batch 666 into cleaned_geolocation.
#
# Inserted batch 667 into cleaned_geolocation.
#
# Inserted batch 668 into cleaned_geolocation.
#
# Inserted batch 669 into cleaned_geolocation.
#
# Inserted batch 670 into cleaned_geolocation.
#
# Inserted batch 671 into cleaned_geolocation.
#
# Inserted batch 672 into cleaned_geolocation.
#
# Inserted batch 673 into cleaned_geolocation.
#
# Inserted batch 674 into cleaned_geolocation.
#
# Inserted batch 675 into cleaned_geolocation.
#
# Inserted batch 676 into cleaned_geolocation.
#
# Inserted batch 677 into cleaned_geolocation.
#
# Inserted batch 678 into cleaned_geolocation.
#
# Inserted batch 679 into cleaned_geolocation.
#
# Inserted batch 680 into cleaned_geolocation.
#
# Inserted batch 681 into cleaned_geolocation.
#
# Inserted batch 682 into cleaned_geolocation.
#
# Inserted batch 683 into cleaned_geolocation.
#
# Inserted batch 684 into cleaned_geolocation.
#
# Inserted batch 685 into cleaned_geolocation.
#
# Inserted batch 686 into cleaned_geolocation.
#
# Inserted batch 687 into cleaned_geolocation.
#
# Inserted batch 688 into cleaned_geolocation.
#
# Inserted batch 689 into cleaned_geolocation.
#
# Inserted batch 690 into cleaned_geolocation.
#
# Inserted batch 691 into cleaned_geolocation.
#
# Inserted batch 692 into cleaned_geolocation.
#
# Inserted batch 693 into cleaned_geolocation.
#
# Inserted batch 694 into cleaned_geolocation.
#
# Inserted batch 695 into cleaned_geolocation.
#
# Inserted batch 696 into cleaned_geolocation.
#
# Inserted batch 697 into cleaned_geolocation.
#
# Inserted batch 698 into cleaned_geolocation.
#
# Inserted batch 699 into cleaned_geolocation.
#
# Inserted batch 700 into cleaned_geolocation.
#
# Inserted batch 701 into cleaned_geolocation.
#
# Inserted batch 702 into cleaned_geolocation.
#
# Inserted batch 703 into cleaned_geolocation.
#
# Inserted batch 704 into cleaned_geolocation.
#
# Inserted batch 705 into cleaned_geolocation.
#
# Inserted batch 706 into cleaned_geolocation.
#
# Inserted batch 707 into cleaned_geolocation.
#
# Inserted batch 708 into cleaned_geolocation.
#
# Inserted batch 709 into cleaned_geolocation.
#
# Inserted batch 710 into cleaned_geolocation.
#
# Inserted batch 711 into cleaned_geolocation.
#
# Inserted batch 712 into cleaned_geolocation.
#
# Inserted batch 713 into cleaned_geolocation.
#
# Inserted batch 714 into cleaned_geolocation.
#
# Inserted batch 715 into cleaned_geolocation.
#
# Inserted batch 716 into cleaned_geolocation.
#
# Inserted batch 717 into cleaned_geolocation.
#
# Inserted batch 718 into cleaned_geolocation.
#
# Inserted batch 719 into cleaned_geolocation.
#
# Inserted batch 720 into cleaned_geolocation.
#
# Inserted batch 721 into cleaned_geolocation.
#
# Inserted batch 722 into cleaned_geolocation.
#
# Inserted batch 723 into cleaned_geolocation.
#
# Inserted batch 724 into cleaned_geolocation.
#
# Inserted batch 725 into cleaned_geolocation.
#
# Inserted batch 726 into cleaned_geolocation.
#
# Inserted batch 727 into cleaned_geolocation.
#
# Inserted batch 728 into cleaned_geolocation.
#
# Inserted batch 729 into cleaned_geolocation.
#
# Inserted batch 730 into cleaned_geolocation.
#
# Inserted batch 731 into cleaned_geolocation.
#
# Inserted batch 732 into cleaned_geolocation.
#
# Inserted batch 733 into cleaned_geolocation.
#
# Inserted batch 734 into cleaned_geolocation.
#
# Inserted batch 735 into cleaned_geolocation.
#
# Inserted batch 736 into cleaned_geolocation.
#
# Inserted batch 737 into cleaned_geolocation.
#
# Inserted batch 738 into cleaned_geolocation.
#
# Inserted batch 739 into cleaned_geolocation.
#
# Processing cleaned_order_items.csv
# NaN values before replacement:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# total_order_value      0
# dtype: int64
#
# Created table cleaned_order_items if not already exists.
# Inserted batch 1 into cleaned_order_items.
#
# Inserted batch 2 into cleaned_order_items.
#
# Inserted batch 3 into cleaned_order_items.
#
# Inserted batch 4 into cleaned_order_items.
#
# Inserted batch 5 into cleaned_order_items.
#
# Inserted batch 6 into cleaned_order_items.
#
# Inserted batch 7 into cleaned_order_items.
#
# Inserted batch 8 into cleaned_order_items.
#
# Inserted batch 9 into cleaned_order_items.
#
# Inserted batch 10 into cleaned_order_items.
#
# Inserted batch 11 into cleaned_order_items.
#
# Inserted batch 12 into cleaned_order_items.
#
# Inserted batch 13 into cleaned_order_items.
#
# Inserted batch 14 into cleaned_order_items.
#
# Inserted batch 15 into cleaned_order_items.
#
# Inserted batch 16 into cleaned_order_items.
#
# Inserted batch 17 into cleaned_order_items.
#
# Inserted batch 18 into cleaned_order_items.
#
# Inserted batch 19 into cleaned_order_items.
#
# Inserted batch 20 into cleaned_order_items.
#
# Inserted batch 21 into cleaned_order_items.
#
# Inserted batch 22 into cleaned_order_items.
#
# Inserted batch 23 into cleaned_order_items.
#
# Inserted batch 24 into cleaned_order_items.
#
# Inserted batch 25 into cleaned_order_items.
#
# Inserted batch 26 into cleaned_order_items.
#
# Inserted batch 27 into cleaned_order_items.
#
# Inserted batch 28 into cleaned_order_items.
#
# Inserted batch 29 into cleaned_order_items.
#
# Inserted batch 30 into cleaned_order_items.
#
# Inserted batch 31 into cleaned_order_items.
#
# Inserted batch 32 into cleaned_order_items.
#
# Inserted batch 33 into cleaned_order_items.
#
# Inserted batch 34 into cleaned_order_items.
#
# Inserted batch 35 into cleaned_order_items.
#
# Inserted batch 36 into cleaned_order_items.
#
# Inserted batch 37 into cleaned_order_items.
#
# Inserted batch 38 into cleaned_order_items.
#
# Inserted batch 39 into cleaned_order_items.
#
# Inserted batch 40 into cleaned_order_items.
#
# Inserted batch 41 into cleaned_order_items.
#
# Inserted batch 42 into cleaned_order_items.
#
# Inserted batch 43 into cleaned_order_items.
#
# Inserted batch 44 into cleaned_order_items.
#
# Inserted batch 45 into cleaned_order_items.
#
# Inserted batch 46 into cleaned_order_items.
#
# Inserted batch 47 into cleaned_order_items.
#
# Inserted batch 48 into cleaned_order_items.
#
# Inserted batch 49 into cleaned_order_items.
#
# Inserted batch 50 into cleaned_order_items.
#
# Inserted batch 51 into cleaned_order_items.
#
# Inserted batch 52 into cleaned_order_items.
#
# Inserted batch 53 into cleaned_order_items.
#
# Inserted batch 54 into cleaned_order_items.
#
# Inserted batch 55 into cleaned_order_items.
#
# Inserted batch 56 into cleaned_order_items.
#
# Inserted batch 57 into cleaned_order_items.
#
# Inserted batch 58 into cleaned_order_items.
#
# Inserted batch 59 into cleaned_order_items.
#
# Inserted batch 60 into cleaned_order_items.
#
# Inserted batch 61 into cleaned_order_items.
#
# Inserted batch 62 into cleaned_order_items.
#
# Inserted batch 63 into cleaned_order_items.
#
# Inserted batch 64 into cleaned_order_items.
#
# Inserted batch 65 into cleaned_order_items.
#
# Inserted batch 66 into cleaned_order_items.
#
# Inserted batch 67 into cleaned_order_items.
#
# Inserted batch 68 into cleaned_order_items.
#
# Inserted batch 69 into cleaned_order_items.
#
# Inserted batch 70 into cleaned_order_items.
#
# Inserted batch 71 into cleaned_order_items.
#
# Inserted batch 72 into cleaned_order_items.
#
# Inserted batch 73 into cleaned_order_items.
#
# Inserted batch 74 into cleaned_order_items.
#
# Inserted batch 75 into cleaned_order_items.
#
# Inserted batch 76 into cleaned_order_items.
#
# Inserted batch 77 into cleaned_order_items.
#
# Inserted batch 78 into cleaned_order_items.
#
# Inserted batch 79 into cleaned_order_items.
#
# Inserted batch 80 into cleaned_order_items.
#
# Inserted batch 81 into cleaned_order_items.
#
# Inserted batch 82 into cleaned_order_items.
#
# Inserted batch 83 into cleaned_order_items.
#
# Inserted batch 84 into cleaned_order_items.
#
# Inserted batch 85 into cleaned_order_items.
#
# Inserted batch 86 into cleaned_order_items.
#
# Inserted batch 87 into cleaned_order_items.
#
# Inserted batch 88 into cleaned_order_items.
#
# Inserted batch 89 into cleaned_order_items.
#
# Inserted batch 90 into cleaned_order_items.
#
# Inserted batch 91 into cleaned_order_items.
#
# Inserted batch 92 into cleaned_order_items.
#
# Inserted batch 93 into cleaned_order_items.
#
# Inserted batch 94 into cleaned_order_items.
#
# Inserted batch 95 into cleaned_order_items.
#
# Inserted batch 96 into cleaned_order_items.
#
# Inserted batch 97 into cleaned_order_items.
#
# Inserted batch 98 into cleaned_order_items.
#
# Inserted batch 99 into cleaned_order_items.
#
# Inserted batch 100 into cleaned_order_items.
#
# Inserted batch 101 into cleaned_order_items.
#
# Inserted batch 102 into cleaned_order_items.
#
# Inserted batch 103 into cleaned_order_items.
#
# Inserted batch 104 into cleaned_order_items.
#
# Inserted batch 105 into cleaned_order_items.
#
# Inserted batch 106 into cleaned_order_items.
#
# Inserted batch 107 into cleaned_order_items.
#
# Inserted batch 108 into cleaned_order_items.
#
# Inserted batch 109 into cleaned_order_items.
#
# Inserted batch 110 into cleaned_order_items.
#
# Inserted batch 111 into cleaned_order_items.
#
# Inserted batch 112 into cleaned_order_items.
#
# Inserted batch 113 into cleaned_order_items.
#
# Processing cleaned_order_payments.csv
# NaN values before replacement:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Created table cleaned_order_payments if not already exists.
# Inserted batch 1 into cleaned_order_payments.
#
# Inserted batch 2 into cleaned_order_payments.
#
# Inserted batch 3 into cleaned_order_payments.
#
# Inserted batch 4 into cleaned_order_payments.
#
# Inserted batch 5 into cleaned_order_payments.
#
# Inserted batch 6 into cleaned_order_payments.
#
# Inserted batch 7 into cleaned_order_payments.
#
# Inserted batch 8 into cleaned_order_payments.
#
# Inserted batch 9 into cleaned_order_payments.
#
# Inserted batch 10 into cleaned_order_payments.
#
# Inserted batch 11 into cleaned_order_payments.
#
# Inserted batch 12 into cleaned_order_payments.
#
# Inserted batch 13 into cleaned_order_payments.
#
# Inserted batch 14 into cleaned_order_payments.
#
# Inserted batch 15 into cleaned_order_payments.
#
# Inserted batch 16 into cleaned_order_payments.
#
# Inserted batch 17 into cleaned_order_payments.
#
# Inserted batch 18 into cleaned_order_payments.
#
# Inserted batch 19 into cleaned_order_payments.
#
# Inserted batch 20 into cleaned_order_payments.
#
# Inserted batch 21 into cleaned_order_payments.
#
# Inserted batch 22 into cleaned_order_payments.
#
# Inserted batch 23 into cleaned_order_payments.
#
# Inserted batch 24 into cleaned_order_payments.
#
# Inserted batch 25 into cleaned_order_payments.
#
# Inserted batch 26 into cleaned_order_payments.
#
# Inserted batch 27 into cleaned_order_payments.
#
# Inserted batch 28 into cleaned_order_payments.
#
# Inserted batch 29 into cleaned_order_payments.
#
# Inserted batch 30 into cleaned_order_payments.
#
# Inserted batch 31 into cleaned_order_payments.
#
# Inserted batch 32 into cleaned_order_payments.
#
# Inserted batch 33 into cleaned_order_payments.
#
# Inserted batch 34 into cleaned_order_payments.
#
# Inserted batch 35 into cleaned_order_payments.
#
# Inserted batch 36 into cleaned_order_payments.
#
# Inserted batch 37 into cleaned_order_payments.
#
# Inserted batch 38 into cleaned_order_payments.
#
# Inserted batch 39 into cleaned_order_payments.
#
# Inserted batch 40 into cleaned_order_payments.
#
# Inserted batch 41 into cleaned_order_payments.
#
# Inserted batch 42 into cleaned_order_payments.
#
# Inserted batch 43 into cleaned_order_payments.
#
# Inserted batch 44 into cleaned_order_payments.
#
# Inserted batch 45 into cleaned_order_payments.
#
# Inserted batch 46 into cleaned_order_payments.
#
# Inserted batch 47 into cleaned_order_payments.
#
# Inserted batch 48 into cleaned_order_payments.
#
# Inserted batch 49 into cleaned_order_payments.
#
# Inserted batch 50 into cleaned_order_payments.
#
# Inserted batch 51 into cleaned_order_payments.
#
# Inserted batch 52 into cleaned_order_payments.
#
# Inserted batch 53 into cleaned_order_payments.
#
# Inserted batch 54 into cleaned_order_payments.
#
# Inserted batch 55 into cleaned_order_payments.
#
# Inserted batch 56 into cleaned_order_payments.
#
# Inserted batch 57 into cleaned_order_payments.
#
# Inserted batch 58 into cleaned_order_payments.
#
# Inserted batch 59 into cleaned_order_payments.
#
# Inserted batch 60 into cleaned_order_payments.
#
# Inserted batch 61 into cleaned_order_payments.
#
# Inserted batch 62 into cleaned_order_payments.
#
# Inserted batch 63 into cleaned_order_payments.
#
# Inserted batch 64 into cleaned_order_payments.
#
# Inserted batch 65 into cleaned_order_payments.
#
# Inserted batch 66 into cleaned_order_payments.
#
# Inserted batch 67 into cleaned_order_payments.
#
# Inserted batch 68 into cleaned_order_payments.
#
# Inserted batch 69 into cleaned_order_payments.
#
# Inserted batch 70 into cleaned_order_payments.
#
# Inserted batch 71 into cleaned_order_payments.
#
# Inserted batch 72 into cleaned_order_payments.
#
# Inserted batch 73 into cleaned_order_payments.
#
# Inserted batch 74 into cleaned_order_payments.
#
# Inserted batch 75 into cleaned_order_payments.
#
# Inserted batch 76 into cleaned_order_payments.
#
# Inserted batch 77 into cleaned_order_payments.
#
# Inserted batch 78 into cleaned_order_payments.
#
# Inserted batch 79 into cleaned_order_payments.
#
# Inserted batch 80 into cleaned_order_payments.
#
# Inserted batch 81 into cleaned_order_payments.
#
# Inserted batch 82 into cleaned_order_payments.
#
# Inserted batch 83 into cleaned_order_payments.
#
# Inserted batch 84 into cleaned_order_payments.
#
# Inserted batch 85 into cleaned_order_payments.
#
# Inserted batch 86 into cleaned_order_payments.
#
# Inserted batch 87 into cleaned_order_payments.
#
# Inserted batch 88 into cleaned_order_payments.
#
# Inserted batch 89 into cleaned_order_payments.
#
# Inserted batch 90 into cleaned_order_payments.
#
# Inserted batch 91 into cleaned_order_payments.
#
# Inserted batch 92 into cleaned_order_payments.
#
# Inserted batch 93 into cleaned_order_payments.
#
# Inserted batch 94 into cleaned_order_payments.
#
# Inserted batch 95 into cleaned_order_payments.
#
# Inserted batch 96 into cleaned_order_payments.
#
# Inserted batch 97 into cleaned_order_payments.
#
# Inserted batch 98 into cleaned_order_payments.
#
# Inserted batch 99 into cleaned_order_payments.
#
# Inserted batch 100 into cleaned_order_payments.
#
# Inserted batch 101 into cleaned_order_payments.
#
# Inserted batch 102 into cleaned_order_payments.
#
# Inserted batch 103 into cleaned_order_payments.
#
# Inserted batch 104 into cleaned_order_payments.
#
# Processing cleaned_order_reviews.csv
# NaN values before replacement:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64
#
# Created table cleaned_order_reviews if not already exists.
# Inserted batch 1 into cleaned_order_reviews.
#
# Inserted batch 2 into cleaned_order_reviews.
#
# Inserted batch 3 into cleaned_order_reviews.
#
# Inserted batch 4 into cleaned_order_reviews.
#
# Inserted batch 5 into cleaned_order_reviews.
#
# Inserted batch 6 into cleaned_order_reviews.
#
# Inserted batch 7 into cleaned_order_reviews.
#
# Inserted batch 8 into cleaned_order_reviews.
#
# Inserted batch 9 into cleaned_order_reviews.
#
# Inserted batch 10 into cleaned_order_reviews.
#
# Inserted batch 11 into cleaned_order_reviews.
#
# Inserted batch 12 into cleaned_order_reviews.
#
# Inserted batch 13 into cleaned_order_reviews.
#
# Inserted batch 14 into cleaned_order_reviews.
#
# Inserted batch 15 into cleaned_order_reviews.
#
# Inserted batch 16 into cleaned_order_reviews.
#
# Inserted batch 17 into cleaned_order_reviews.
#
# Inserted batch 18 into cleaned_order_reviews.
#
# Inserted batch 19 into cleaned_order_reviews.
#
# Inserted batch 20 into cleaned_order_reviews.
#
# Inserted batch 21 into cleaned_order_reviews.
#
# Inserted batch 22 into cleaned_order_reviews.
#
# Inserted batch 23 into cleaned_order_reviews.
#
# Inserted batch 24 into cleaned_order_reviews.
#
# Inserted batch 25 into cleaned_order_reviews.
#
# Inserted batch 26 into cleaned_order_reviews.
#
# Inserted batch 27 into cleaned_order_reviews.
#
# Inserted batch 28 into cleaned_order_reviews.
#
# Inserted batch 29 into cleaned_order_reviews.
#
# Inserted batch 30 into cleaned_order_reviews.
#
# Inserted batch 31 into cleaned_order_reviews.
#
# Inserted batch 32 into cleaned_order_reviews.
#
# Inserted batch 33 into cleaned_order_reviews.
#
# Inserted batch 34 into cleaned_order_reviews.
#
# Inserted batch 35 into cleaned_order_reviews.
#
# Inserted batch 36 into cleaned_order_reviews.
#
# Inserted batch 37 into cleaned_order_reviews.
#
# Inserted batch 38 into cleaned_order_reviews.
#
# Inserted batch 39 into cleaned_order_reviews.
#
# Inserted batch 40 into cleaned_order_reviews.
#
# Inserted batch 41 into cleaned_order_reviews.
#
# Inserted batch 42 into cleaned_order_reviews.
#
# Inserted batch 43 into cleaned_order_reviews.
#
# Inserted batch 44 into cleaned_order_reviews.
#
# Inserted batch 45 into cleaned_order_reviews.
#
# Inserted batch 46 into cleaned_order_reviews.
#
# Inserted batch 47 into cleaned_order_reviews.
#
# Inserted batch 48 into cleaned_order_reviews.
#
# Inserted batch 49 into cleaned_order_reviews.
#
# Inserted batch 50 into cleaned_order_reviews.
#
# Inserted batch 51 into cleaned_order_reviews.
#
# Inserted batch 52 into cleaned_order_reviews.
#
# Inserted batch 53 into cleaned_order_reviews.
#
# Inserted batch 54 into cleaned_order_reviews.
#
# Inserted batch 55 into cleaned_order_reviews.
#
# Inserted batch 56 into cleaned_order_reviews.
#
# Inserted batch 57 into cleaned_order_reviews.
#
# Inserted batch 58 into cleaned_order_reviews.
#
# Inserted batch 59 into cleaned_order_reviews.
#
# Inserted batch 60 into cleaned_order_reviews.
#
# Inserted batch 61 into cleaned_order_reviews.
#
# Inserted batch 62 into cleaned_order_reviews.
#
# Inserted batch 63 into cleaned_order_reviews.
#
# Inserted batch 64 into cleaned_order_reviews.
#
# Inserted batch 65 into cleaned_order_reviews.
#
# Inserted batch 66 into cleaned_order_reviews.
#
# Inserted batch 67 into cleaned_order_reviews.
#
# Inserted batch 68 into cleaned_order_reviews.
#
# Inserted batch 69 into cleaned_order_reviews.
#
# Inserted batch 70 into cleaned_order_reviews.
#
# Inserted batch 71 into cleaned_order_reviews.
#
# Inserted batch 72 into cleaned_order_reviews.
#
# Inserted batch 73 into cleaned_order_reviews.
#
# Inserted batch 74 into cleaned_order_reviews.
#
# Inserted batch 75 into cleaned_order_reviews.
#
# Inserted batch 76 into cleaned_order_reviews.
#
# Inserted batch 77 into cleaned_order_reviews.
#
# Inserted batch 78 into cleaned_order_reviews.
#
# Inserted batch 79 into cleaned_order_reviews.
#
# Inserted batch 80 into cleaned_order_reviews.
#
# Inserted batch 81 into cleaned_order_reviews.
#
# Inserted batch 82 into cleaned_order_reviews.
#
# Inserted batch 83 into cleaned_order_reviews.
#
# Inserted batch 84 into cleaned_order_reviews.
#
# Inserted batch 85 into cleaned_order_reviews.
#
# Inserted batch 86 into cleaned_order_reviews.
#
# Inserted batch 87 into cleaned_order_reviews.
#
# Inserted batch 88 into cleaned_order_reviews.
#
# Inserted batch 89 into cleaned_order_reviews.
#
# Inserted batch 90 into cleaned_order_reviews.
#
# Inserted batch 91 into cleaned_order_reviews.
#
# Inserted batch 92 into cleaned_order_reviews.
#
# Inserted batch 93 into cleaned_order_reviews.
#
# Inserted batch 94 into cleaned_order_reviews.
#
# Inserted batch 95 into cleaned_order_reviews.
#
# Inserted batch 96 into cleaned_order_reviews.
#
# Inserted batch 97 into cleaned_order_reviews.
#
# Inserted batch 98 into cleaned_order_reviews.
#
# Inserted batch 99 into cleaned_order_reviews.
#
# Inserted batch 100 into cleaned_order_reviews.
#
# Processing cleaned_orders.csv
# NaN values before replacement:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# carrier_delivery_status          0
# customer_delivery_status         0
# order_processing_time            0
# shipping_time                    0
# purchase_year                    0
# purchase_month                   0
# purchase_day_of_week             0
# total_order_value                0
# dtype: int64
#
# Created table cleaned_orders if not already exists.
# Inserted batch 1 into cleaned_orders.
#
# Inserted batch 2 into cleaned_orders.
#
# Inserted batch 3 into cleaned_orders.
#
# Inserted batch 4 into cleaned_orders.
#
# Inserted batch 5 into cleaned_orders.
#
# Inserted batch 6 into cleaned_orders.
#
# Inserted batch 7 into cleaned_orders.
#
# Inserted batch 8 into cleaned_orders.
#
# Inserted batch 9 into cleaned_orders.
#
# Inserted batch 10 into cleaned_orders.
#
# Inserted batch 11 into cleaned_orders.
#
# Inserted batch 12 into cleaned_orders.
#
# Inserted batch 13 into cleaned_orders.
#
# Inserted batch 14 into cleaned_orders.
#
# Inserted batch 15 into cleaned_orders.
#
# Inserted batch 16 into cleaned_orders.
#
# Inserted batch 17 into cleaned_orders.
#
# Inserted batch 18 into cleaned_orders.
#
# Inserted batch 19 into cleaned_orders.
#
# Inserted batch 20 into cleaned_orders.
#
# Inserted batch 21 into cleaned_orders.
#
# Inserted batch 22 into cleaned_orders.
#
# Inserted batch 23 into cleaned_orders.
#
# Inserted batch 24 into cleaned_orders.
#
# Inserted batch 25 into cleaned_orders.
#
# Inserted batch 26 into cleaned_orders.
#
# Inserted batch 27 into cleaned_orders.
#
# Inserted batch 28 into cleaned_orders.
#
# Inserted batch 29 into cleaned_orders.
#
# Inserted batch 30 into cleaned_orders.
#
# Inserted batch 31 into cleaned_orders.
#
# Inserted batch 32 into cleaned_orders.
#
# Inserted batch 33 into cleaned_orders.
#
# Inserted batch 34 into cleaned_orders.
#
# Inserted batch 35 into cleaned_orders.
#
# Inserted batch 36 into cleaned_orders.
#
# Inserted batch 37 into cleaned_orders.
#
# Inserted batch 38 into cleaned_orders.
#
# Inserted batch 39 into cleaned_orders.
#
# Inserted batch 40 into cleaned_orders.
#
# Inserted batch 41 into cleaned_orders.
#
# Inserted batch 42 into cleaned_orders.
#
# Inserted batch 43 into cleaned_orders.
#
# Inserted batch 44 into cleaned_orders.
#
# Inserted batch 45 into cleaned_orders.
#
# Inserted batch 46 into cleaned_orders.
#
# Inserted batch 47 into cleaned_orders.
#
# Inserted batch 48 into cleaned_orders.
#
# Inserted batch 49 into cleaned_orders.
#
# Inserted batch 50 into cleaned_orders.
#
# Inserted batch 51 into cleaned_orders.
#
# Inserted batch 52 into cleaned_orders.
#
# Inserted batch 53 into cleaned_orders.
#
# Inserted batch 54 into cleaned_orders.
#
# Inserted batch 55 into cleaned_orders.
#
# Inserted batch 56 into cleaned_orders.
#
# Inserted batch 57 into cleaned_orders.
#
# Inserted batch 58 into cleaned_orders.
#
# Inserted batch 59 into cleaned_orders.
#
# Inserted batch 60 into cleaned_orders.
#
# Inserted batch 61 into cleaned_orders.
#
# Inserted batch 62 into cleaned_orders.
#
# Inserted batch 63 into cleaned_orders.
#
# Inserted batch 64 into cleaned_orders.
#
# Inserted batch 65 into cleaned_orders.
#
# Inserted batch 66 into cleaned_orders.
#
# Inserted batch 67 into cleaned_orders.
#
# Inserted batch 68 into cleaned_orders.
#
# Inserted batch 69 into cleaned_orders.
#
# Inserted batch 70 into cleaned_orders.
#
# Inserted batch 71 into cleaned_orders.
#
# Inserted batch 72 into cleaned_orders.
#
# Inserted batch 73 into cleaned_orders.
#
# Inserted batch 74 into cleaned_orders.
#
# Inserted batch 75 into cleaned_orders.
#
# Inserted batch 76 into cleaned_orders.
#
# Inserted batch 77 into cleaned_orders.
#
# Inserted batch 78 into cleaned_orders.
#
# Inserted batch 79 into cleaned_orders.
#
# Inserted batch 80 into cleaned_orders.
#
# Inserted batch 81 into cleaned_orders.
#
# Inserted batch 82 into cleaned_orders.
#
# Inserted batch 83 into cleaned_orders.
#
# Inserted batch 84 into cleaned_orders.
#
# Inserted batch 85 into cleaned_orders.
#
# Inserted batch 86 into cleaned_orders.
#
# Inserted batch 87 into cleaned_orders.
#
# Inserted batch 88 into cleaned_orders.
#
# Inserted batch 89 into cleaned_orders.
#
# Inserted batch 90 into cleaned_orders.
#
# Inserted batch 91 into cleaned_orders.
#
# Inserted batch 92 into cleaned_orders.
#
# Inserted batch 93 into cleaned_orders.
#
# Inserted batch 94 into cleaned_orders.
#
# Inserted batch 95 into cleaned_orders.
#
# Inserted batch 96 into cleaned_orders.
#
# Inserted batch 97 into cleaned_orders.
#
# Processing cleaned_products.csv
# NaN values before replacement:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64
#
# Created table cleaned_products if not already exists.
# Inserted batch 1 into cleaned_products.
#
# Inserted batch 2 into cleaned_products.
#
# Inserted batch 3 into cleaned_products.
#
# Inserted batch 4 into cleaned_products.
#
# Inserted batch 5 into cleaned_products.
#
# Inserted batch 6 into cleaned_products.
#
# Inserted batch 7 into cleaned_products.
#
# Inserted batch 8 into cleaned_products.
#
# Inserted batch 9 into cleaned_products.
#
# Inserted batch 10 into cleaned_products.
#
# Inserted batch 11 into cleaned_products.
#
# Inserted batch 12 into cleaned_products.
#
# Inserted batch 13 into cleaned_products.
#
# Inserted batch 14 into cleaned_products.
#
# Inserted batch 15 into cleaned_products.
#
# Inserted batch 16 into cleaned_products.
#
# Inserted batch 17 into cleaned_products.
#
# Inserted batch 18 into cleaned_products.
#
# Inserted batch 19 into cleaned_products.
#
# Inserted batch 20 into cleaned_products.
#
# Inserted batch 21 into cleaned_products.
#
# Inserted batch 22 into cleaned_products.
#
# Inserted batch 23 into cleaned_products.
#
# Inserted batch 24 into cleaned_products.
#
# Inserted batch 25 into cleaned_products.
#
# Inserted batch 26 into cleaned_products.
#
# Inserted batch 27 into cleaned_products.
#
# Inserted batch 28 into cleaned_products.
#
# Inserted batch 29 into cleaned_products.
#
# Inserted batch 30 into cleaned_products.
#
# Inserted batch 31 into cleaned_products.
#
# Inserted batch 32 into cleaned_products.
#
# Inserted batch 33 into cleaned_products.
#
# Processing cleaned_sellers.csv
# NaN values before replacement:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Created table cleaned_sellers if not already exists.
# Inserted batch 1 into cleaned_sellers.
#
# Inserted batch 2 into cleaned_sellers.
#
# Inserted batch 3 into cleaned_sellers.
#
# Inserted batch 4 into cleaned_sellers.
#
# Database connection closed.
